# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats library from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
# Now we'll learn about box and violin plots
url = 'http://en.wikipedia.org/wiki/Box_plot#mediaviewer/File:Boxplot_vs_PDF.svg'

# %%
data1 = randn(100)
data2 = randn(100)

# %%
sns.boxplot(data=[data1,data2])

# %%
sns.boxplot(data=[data1,data2],whis=np.inf)

# %%
sns.boxplot(data1,vert=False)
# Out:
# C:\Users\Tayyab Nadeem\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-798b50bb86e8> in <module>
# ----> 1 sns.boxplot(data1,vert=False)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2236     kwargs.update(dict(whis=whis))
#    2237
# -> 2238     plotter.plot(ax, kwargs)
#    2239     return ax
#    2240
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     507     def plot(self, ax, boxplot_kws):
#     508         """Make the plot."""
# --> 509         self.draw_boxplot(ax, boxplot_kws)
#     510         self.annotate_axes(ax)
#     511         if self.orient == "h":
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\categorical.py in draw_boxplot(self, ax, kws)
#     439                     continue
#     440
# --> 441                 artist_dict = ax.boxplot(box_data,
#     442                                          vert=vert,
#     443                                          patch_artist=True,
#
# TypeError: boxplot() got multiple values for keyword argument 'vert'

# %%
#Normal Dist
data1 = stats.norm(0,5).rvs(100)

# Two gamma dist. Concatenated together
data2 = np.concatenate([stats.gamma(5).rvs(50)-1,
                        -1*stats.gamma(5).rvs(50)])

#Box plot both data1 and data2
sns.boxplot(data=[data1,data2],whis=np.inf)

# %%
sns.violinplot(data=[data1,data2])

# %%
sns.violinplot(data2,bw=0.01)
# Out:
# C:\Users\Tayyab Nadeem\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.violinplot(data1,inner="stick")
# Out:
# C:\Users\Tayyab Nadeem\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
