# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website='http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                  Team    GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys   914  520   388     6  0.572              1960
# 1     2     Green Bay Packers  1368  756   574    38  0.567              1921
# 2     3  New England Patriots   916  512   395     9  0.564              1960
# 3     4         Chicago Bears  1402  769   591    42  0.563              1920
# 4     5      Baltimore Ravens   384  214   169     1  0.559              1996
#
#     Division
# 0   NFC East
# 1  NFC North
# 2   AFC East
# 3  NFC North
# 4  AFC North

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame['First NFL Season']
# Out:
# 0    1960
# 1    1921
# 2    1960
# 3    1920
# 4    1996
# Name: First NFL Season, dtype: int64

# %%
DataFrame(nfl_frame,columns=['Team','First NFL Season', 'Total Games'])
# Out:
#                    Team  First NFL Season  Total Games
# 0        Dallas Cowboys              1960          NaN
# 1     Green Bay Packers              1921          NaN
# 2  New England Patriots              1960          NaN
# 3         Chicago Bears              1920          NaN
# 4      Baltimore Ravens              1996          NaN

# %%
nfl_frame
# Out:
#    Rank                  Team    GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys   914  520   388     6  0.572              1960
# 1     2     Green Bay Packers  1368  756   574    38  0.567              1921
# 2     3  New England Patriots   916  512   395     9  0.564              1960
# 3     4         Chicago Bears  1402  769   591    42  0.563              1920
# 4     5      Baltimore Ravens   384  214   169     1  0.559              1996
#
#     Division
# 0   NFC East
# 1  NFC North
# 2   AFC East
# 3  NFC North
# 4  AFC North

# %%
nfl_frame.head(3)
# Out:
#    Rank                  Team    GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys   914  520   388     6  0.572              1960
# 1     2     Green Bay Packers  1368  756   574    38  0.567              1921
# 2     3  New England Patriots   916  512   395     9  0.564              1960
#
#     Division
# 0   NFC East
# 1  NFC North
# 2   AFC East

# %%
nfl_frame.tail(2)
# Out:
#    Rank              Team    GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 3     4     Chicago Bears  1402  769   591    42  0.563              1920
# 4     5  Baltimore Ravens   384  214   169     1  0.559              1996
#
#     Division
# 3  NFC North
# 4  AFC North

# %%
nfl_frame
# Out:
#    Rank                  Team    GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys   914  520   388     6  0.572              1960
# 1     2     Green Bay Packers  1368  756   574    38  0.567              1921
# 2     3  New England Patriots   916  512   395     9  0.564              1960
# 3     4         Chicago Bears  1402  769   591    42  0.563              1920
# 4     5      Baltimore Ravens   384  214   169     1  0.559              1996
#
#     Division
# 0   NFC East
# 1  NFC North
# 2   AFC East
# 3  NFC North
# 4  AFC North

# %%
nfl_frame.ix[3]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-ab12edb6de57> in <module>
# ----> 1 nfl_frame.ix[3]
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank                  Team    GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys   914  520   388     6  0.572              1960
# 1     2     Green Bay Packers  1368  756   574    38  0.567              1921
# 2     3  New England Patriots   916  512   395     9  0.564              1960
# 3     4         Chicago Bears  1402  769   591    42  0.563              1920
# 4     5      Baltimore Ravens   384  214   169     1  0.559              1996
#
#     Division         Stadium
# 0   NFC East  Levi's Stadium
# 1  NFC North  Levi's Stadium
# 2   AFC East  Levi's Stadium
# 3  NFC North  Levi's Stadium
# 4  AFC North  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank                  Team    GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys   914  520   388     6  0.572              1960
# 1     2     Green Bay Packers  1368  756   574    38  0.567              1921
# 2     3  New England Patriots   916  512   395     9  0.564              1960
# 3     4         Chicago Bears  1402  769   591    42  0.563              1920
# 4     5      Baltimore Ravens   384  214   169     1  0.559              1996
#
#     Division  Stadium
# 0   NFC East        0
# 1  NFC North        1
# 2   AFC East        2
# 3  NFC North        3
# 4  AFC North        4

# %%
stadiums = Series(["Levi's Stadium","AT7T Stadium"], index=[4,0])
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT7T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank                  Team    GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys   914  520   388     6  0.572              1960
# 1     2     Green Bay Packers  1368  756   574    38  0.567              1921
# 2     3  New England Patriots   916  512   395     9  0.564              1960
# 3     4         Chicago Bears  1402  769   591    42  0.563              1920
# 4     5      Baltimore Ravens   384  214   169     1  0.559              1996
#
#     Division         Stadium
# 0   NFC East    AT7T Stadium
# 1  NFC North             NaN
# 2   AFC East             NaN
# 3  NFC North             NaN
# 4  AFC North  Levi's Stadium

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank                  Team    GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys   914  520   388     6  0.572              1960
# 1     2     Green Bay Packers  1368  756   574    38  0.567              1921
# 2     3  New England Patriots   916  512   395     9  0.564              1960
# 3     4         Chicago Bears  1402  769   591    42  0.563              1920
# 4     5      Baltimore Ravens   384  214   169     1  0.559              1996
#
#     Division
# 0   NFC East
# 1  NFC North
# 2   AFC East
# 3  NFC North
# 4  AFC North

# %%
data = {'City':['SF','LA','NYC'],'Population':[837000,3880000,8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
#http://pandas.pydata.org/pandas-docs/version/0.16.2/generated/pandas.DataFrame.html
